# %%
# 1. Import Required Libraries
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
import psi4

# 2. Read the SMILES data from your existing 'smiles.csv' file
smiles_df = pd.read_csv("smiles.csv")

# Check the first few rows of the dataframe to ensure it's loaded correctly
print(smiles_df.head())

# 3. Convert SMILES to RDKit Molecules and Compute Atom Counts
def add_chemical_info(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None, None
    n_atoms = mol.GetNumAtoms()
    return mol, n_atoms

smiles_df['ROMol'], smiles_df['n_atoms'] = zip(*smiles_df['smiles'].apply(add_chemical_info))

# 4. Generate 3D Coordinates for RDKit Molecules (If Not Already Present)
def generate_3d_coordinates(mol):
    if mol is None:  # Skip invalid molecules
        return None
    try:
        mol = Chem.AddHs(mol)  # Add hydrogens first (required for 3D generation)
        success = AllChem.EmbedMolecule(mol, randomSeed=42)  # Generate 3D coordinates
        if success != 0:
            print(f"Warning: 3D generation failed for {Chem.MolToSmiles(mol)}")
            return None
        AllChem.UFFOptimizeMolecule(mol)  # Optimize geometry using UFF (Universal Force Field)
        return mol
    except Exception as e:
        print(f"Error generating 3D coordinates for molecule: {e}")
        return None

# Apply 3D coordinate generation to all molecules
smiles_df['3D_mol'] = smiles_df['ROMol'].apply(generate_3d_coordinates)

# 5. Check the DataFrame with the newly added 'ROMol', 'n_atoms', and '3D_mol' columns
print(smiles_df.head())

# 6. Convert RDKit Molecule to XYZ Format
def mol_to_xyz(mol):
    if mol is None:
        return None
    try:
        mol_xyz = Chem.MolToXYZBlock(mol)  # Convert to XYZ format
        return mol_xyz
    except Exception as e:
        print(f"Error converting RDKit molecule to XYZ: {e}")
        return None

# Convert molecules to XYZ format
smiles_df['xyz'] = smiles_df['3D_mol'].apply(mol_to_xyz)

# 7. Set Up Psi4 for Energy Optimization
def compute_energy(mol_xyz):
    if mol_xyz is None:
        return None
    try:
        # Use the XYZ format with Psi4
        psi4.geometry(mol_xyz)  # Define the molecule for Psi4
        energy = psi4.energy('scf/6-31G(d)')  # Perform energy calculation (single-point)
        return energy
    except Exception as e:
        print(f"Error calculating energy: {e}")
        return None

# 8. Perform Energy Calculations and Add to DataFrame
# We will now add the energy values as a new column to the DataFrame.
smiles_df['energy'] = smiles_df['xyz'].apply(compute_energy)
# Out:
#         smiles
# 0     C1CCCCC1
# 1  C1=CC=CC=C1
# 2      CC(=O)O
# 3     C1COCCO1
# 4          CCO
#         smiles                                             ROMol  n_atoms  \
# 0     C1CCCCC1  <rdkit.Chem.rdchem.Mol object at 0x1508481cb350>      6.0
# 1  C1=CC=CC=C1  <rdkit.Chem.rdchem.Mol object at 0x1508481cb270>      6.0
# 2      CC(=O)O  <rdkit.Chem.rdchem.Mol object at 0x1508481cb2e0>      4.0
# 3     C1COCCO1  <rdkit.Chem.rdchem.Mol object at 0x1508481cb200>      6.0
# 4          CCO  <rdkit.Chem.rdchem.Mol object at 0x1508481cb190>      3.0
#
#                                              3D_mol
# 0  <rdkit.Chem.rdchem.Mol object at 0x1508481cb820>
# 1  <rdkit.Chem.rdchem.Mol object at 0x1508481cbb30>
# 2  <rdkit.Chem.rdchem.Mol object at 0x1508481cb6d0>
# 3  <rdkit.Chem.rdchem.Mol object at 0x1508481cb430>
# 4  <rdkit.Chem.rdchem.Mol object at 0x1508481cba50>
#
# Scratch directory: /tmp/
#
# *** tstart() called on cm024.hpc.nyu.edu
# *** at Thu Nov 14 15:39:58 2024
#
#    => Loading Basis Set <=
#
#     Name: 6-31G(D)
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-
#       64A      1.518831    65A      1.664790    66A      1.696690
#       67A      1.696690    68A      1.765767    69A      1.765767
#       70A      1.795632    71A      1.795632    72A      2.048830
#       73A      2.088984    74A      2.158717    75A      2.173302
#       76A      2.307617    77A      2.307617    78A      2.388882
#       79A      2.388882    80A      2.465963    81A      2.465964
#       82A      2.469057    83A      2.469057    84A      2.635428
#       85A      2.635429    86A      2.642572    87A      2.880158
#       88A      2.880158    89A      2.995679    90A      3.067688
#       91A      3.067688    92A      3.079740    93A      3.079740
#       94A      3.088427    95A      3.388907    96A      3.784835
#       97A      4.509727    98A      4.542850    99A      4.542850
#      100A      4.755685   101A      4.755685   102A      5.093822
#
#     Final Occupation by Irrep:
#               A
#     DOCC [    21 ]
#     NA   [    21 ]
#     NB   [    21 ]
#
#   @DF-RHF Final Energy:  -230.70159152275352
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =            203.0193347806511497
#     One-Electron Energy =                -712.5805620449779099
#     Two-Electron Energy =                 278.8596357415732427
#     Total Energy =                       -230.7015915227535174
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000002           -0.0000009           -0.0000006
#  Dipole Y            :          0.0000011           -0.0000009            0.0000002
#  Dipole Z            :          0.0000320           -0.0000450           -0.0000129
#  Magnitude           :                                                    0.0000129
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on cm024.hpc.nyu.edu at Thu Nov 14 15:40:01 2024
# Module time:
# 	user time   =       1.27 seconds =       0.02 minutes
# 	system time =       0.05 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =      28.01 seconds =       0.47 minutes
# 	system time =       1.36 seconds =       0.02 minutes
# 	total time  =        210 seconds =       3.50 minutes
#
# Scratch directory: /tmp/
#
# *** tstart() called on cm024.hpc.nyu.edu
# *** at Thu Nov 14 15:40:02 2024
#
#    => Loading Basis Set <=
#
#     Name: 6-31G(D)
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry C          line   111 file /ext3/miniconda3/share/psi4/basis/6-31g_d_.gbs
#     atoms 3-4 entry O          line   145 file /ext3/miniconda3/share/psi4/basis/6-31g_d_.gbs
#     atoms 5-8 entry H          line    44 file /ext3/miniconda3/share/psi4/basis/6-31g_d_.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C           -1.422953064130    -0.303273064349    -0.277729208069    12.000000000000
#          C            0.001137935870     0.051671935651    -0.014631208069    12.000000000000
#          O            0.350408935870     1.261226935651     0.031335791931    15.994914619570
#          O            0.933492935870    -0.952309064349     0.226318791931    15.994914619570
#          H           -1.858110064130     0.394715935651    -1.023784208069     1.007825032230
#          H           -2.001269064130    -0.237308064349     0.667145791931     1.007825032230
#          H           -1.489050064130    -1.338189064349    -0.674042208069     1.007825032230
#          H            1.901283935870    -0.726198064349     0.422600791931     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      0.37432  B =      0.29188  C =      0.16946 [cm^-1]
#   Rotational constants: A =  11221.91508  B =   8750.47447  C =   5080.30468 [MHz]
#   Nuclear repulsion =  118.044147330475212
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 32
#   Nalpha       = 16
#   Nbeta        = 16
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-31G(D)
#     Blend: 6-31G(D)
#     Number of shells: 32
#     Number of basis functions: 68
#     Number of Cartesian functions: 68
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (6-31G(D) AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2 entry C          line   121 file /ext3/miniconda3/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 3-4 entry O          line   221 file /ext3/miniconda3/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 5-8 entry H          line    51 file /ext3/miniconda3/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.017 GiB; user supplied 0.366 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.1298
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G(D) AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 132
#     Number of basis functions: 424
#     Number of Cartesian functions: 424
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 5.4060737494E-03.
#   Reciprocal condition number of the overlap matrix is 8.3506740319E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         68      68
#    -------------------------
#     Total      68      68
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter SAD:  
#       46A      0.849173    47A      0.890985    48A      0.911742
#       49A      1.050765    50A      1.053385    51A      1.063281
#       52A      1.096729    53A      1.100234    54A      1.113664
#       55A      1.121182    56A      1.159422    57A      1.165686
#       58A      1.190678    59A      1.204203    60A      1.206054
#       61A      1.335673    62A      1.421584    63A      1.421930
#       64A      1.460954    65A      1.538971    66A      1.642978
#       67A      1.663086    68A      1.674113    69A      1.692495
#       70A      1.732131    71A      1.836742    72A      1.906468
#       73A      1.921478    74A      1.993821    75A      2.044404
#       76A      2.092273    77A      2.157809    78A      2.219502
#       79A      2.304099    80A      2.313993    81A      2.355578
#       82A      2.387628    83A      2.423645    84A      2.436090
#       85A      2.457472    86A      2.480197    87A      2.507240
#       88A      2.608507    89A      2.719637    90A      2.746953
#       91A      2.760436    92A      2.802808    93A      2.821347
#       94A      2.937898    95A      3.045240    96A      3.055130
#       97A      3.079375    98A      3.127261    99A      3.310309
#      100A      3.317007   101A      4.277267   102A      4.449755
#      103A      4.594856   104A      4.725909   105A      4.887799
#      106A      4.917517
#
#     Final Occupation by Irrep:
#               A
#     DOCC [    24 ]
#     NA   [    24 ]
#     NB   [    24 ]
#
#   @DF-RHF Final Energy:  -305.81912977015406
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =            263.8699457895772298
#     One-Electron Energy =                -940.5902586093827722
#     Two-Electron Energy =                 370.9011830496514222
#     Total Energy =                       -305.8191297701540634
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000023            0.0000017           -0.0000006
#  Dipole Y            :         -0.0000018            0.0000009           -0.0000009
#  Dipole Z            :         -0.0000003            0.0000000           -0.0000003
#  Magnitude           :                                                    0.0000011
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on cm024.hpc.nyu.edu at Thu Nov 14 15:40:04 2024
# Module time:
# 	user time   =       1.70 seconds =       0.03 minutes
# 	system time =       0.07 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
# Total time:
# 	user time   =      30.49 seconds =       0.51 minutes
# 	system time =       1.45 seconds =       0.02 minutes
# 	total time  =        213 seconds =       3.55 minutes
#
# Scratch directory: /tmp/
#
# *** tstart() called on cm024.hpc.nyu.edu
# *** at Thu Nov 14 15:40:04 2024
#
#    => Loading Basis Set <=
#
#     Name: 6-31G(D)
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry C          line   111 file /ext3/miniconda3/share/psi4/basis/6-31g_d_.gbs
#     atoms 3   entry O          line   145 file /ext3/miniconda3/share/psi4/basis/6-31g_d_.gbs
#     atoms 4-9 entry H          line    44 file /ext3/miniconda3/share/psi4/basis/6-31g_d_.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C           -1.273843796426     0.009101707958    -0.165321322276    12.000000000000
#          C            0.164979203574    -0.483904292042    -0.258058322276    12.000000000000
#          O            1.024014203574     0.387420707958     0.425343677724    15.994914619570
#          H           -1.367270796426     1.006284707958    -0.645271322276     1.007825032230
#          H           -1.947965796426    -0.704004292042    -0.684942322276     1.007825032230
#          H           -1.581544796426     0.085624707958     0.899106677724     1.007825032230
#          H            0.467950203574    -0.574243292042    -1.325905322276     1.007825032230
#          H            0.234294203574    -1.490504292042     0.205665677724     1.007825032230
#          H            1.145749203574     1.181587707958    -0.158057322276     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      1.11276  B =      0.31456  C =      0.27805 [cm^-1]
#   Rotational constants: A =  33359.75079  B =   9430.25878  C =   8335.69135 [MHz]
#   Nuclear repulsion =   81.727567489996488
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 26
#   Nalpha       = 13
#   Nbeta        = 13
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-31G(D)
#     Blend: 6-31G(D)
#     Number of shells: 30
#     Number of basis functions: 57
#     Number of Cartesian functions: 57
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (6-31G(D) AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2 entry C          line   121 file /ext3/miniconda3/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 3   entry O          line   221 file /ext3/miniconda3/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 4-9 entry H          line    51 file /ext3/miniconda3/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.011 GiB; user supplied 0.366 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0616
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G(D) AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 126
#     Number of basis functions: 393
#     Number of Cartesian functions: 393
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 6.0465864247E-03.
#   Reciprocal condition number of the overlap matrix is 9.0952566501E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         57      57
#    -------------------------
#     Total      57      57
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter SAD:  -153.28255620819735   -1.53283e+02   0.00000e+00
#    @DF-RHF iter   1:  -153.97788635807979   -6.95330e-01   7.20801e-03 ADIIS/DIIS
#    @DF-RHF iter   2:  -154.05264837625194   -7.47620e-02   3.70634e-03 ADIIS/DIIS
#    @DF-RHF iter   3:  -154.06907698998486   -1.64286e-02   6.70455e-04 ADIIS/DIIS
#    @DF-RHF iter   4:  -154.07010637513807   -1.02939e-03   2.01124e-04 ADIIS/DIIS
#    @DF-RHF iter   5:  -154.07018528054141   -7.89054e-05   4.38820e-05 DIIS
#    @DF-RHF iter   6:  -154.07019028081228   -5.00027e-06   9.18894e-06 DIIS
#    @DF-RHF iter   7:  -154.07019060549857   -3.24686e-07   2.21222e-06 DIIS
#    @DF-RHF iter   8:  -154.07019062630093   -2.08024e-08   6.74542e-07 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.560741     2A    -11.277884     3A    -11.221546
#        4A     -1.355211     5A     -1.003636     6A     -0.834071
#        7A     -0.686947     8A     -0.624079     9A     -0.590953
#       10A     -0.543634    11A     -0.521121    12A     -0.472209
#       13A     -0.433773
#
#     Virtual:
#
#       14A      0.211819    15A      0.264689    16A      0.293653
#       17A      0.308487    18A      0.315666    19A      0.338544
#       20A      0.411592    21A      0.414003    22A      0.729159
#       23A      0.760810    24A      0.799068    25A      0.818457
#       26A      0.905228    27A      0.913175    28A      1.052275
#       29A      1.118974    30A      1.140755    31A      1.158274
#       32A      1.170757    33A      1.187659    34A      1.214052
#       35A      1.268582    36A      1.303083    37A      1.426346
#       38A      1.637761    39A      1.713678    40A      1.788708
#       41A      1.838464    42A      2.040368    43A      2.110629
#       44A      2.220319    45A      2.262800    46A      2.429763
#       47A      2.470080    48A      2.549736    49A      2.622538
#       50A      2.686715    51A      2.742954    52A      2.832249
#       53A      2.996974    54A      3.191307    55A      4.147320
#       56A      4.587977    57A      4.813303
#
#     Final Occupation by Irrep:
#               A
#     DOCC [    13 ]
#     NA   [    13 ]
#     NB   [    13 ]
#
#   @DF-RHF Final Energy:  -154.07019062630093
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             81.7275674899964883
#     One-Electron Energy =                -371.3439692416496314
#     Two-Electron Energy =                 135.5462111253522153
#     Total Energy =                       -154.0701906263009278
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          2.5643360           -2.8532251           -0.2888891
#  Dipole Y            :          0.5992015           -0.4624247            0.1367769
#  Dipole Z            :          0.9556251           -1.6004702           -0.6448451
# ...
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.564156     2A    -15.552682     3A    -11.277776
#        4A    -11.277761     5A    -11.254942     6A    -11.254926
#        7A     -1.381145     8A     -1.201446     9A     -1.030550
#       10A     -0.918572    11A     -0.869042    12A     -0.793517
#       13A     -0.680349    14A     -0.641701    15A     -0.636961
#       16A     -0.631871    17A     -0.600094    18A     -0.537300
#       19A     -0.531503    20A     -0.504156    21A     -0.487685
#       22A     -0.478107    23A     -0.442701    24A     -0.350224
#
#     Virtual:
#
#       25A      0.220092    26A      0.256390    27A      0.271798
#       28A      0.276006    29A      0.300426    30A      0.313053
#          H            1.315155176962     0.387194498115     1.446603907743     1.007825032230
#          H            0.661753176962    -1.257845501885     1.397184907743     1.007825032230
#          H           -0.607276823038     1.705326498115     1.336193907743     1.007825032230
#          H           -1.523812823038     1.804863498115    -0.202297092257     1.007825032230
#          H            0.591621176962     2.217951498115    -1.478245092257     1.007825032230
#          H            1.488397176962     2.313681498115     0.091078907743     1.007825032230
#          H            0.183990176962     3.496760498115    -0.270959092257     1.007825032230
#          H           -2.342110823038    -0.255324501885    -0.264181092257     1.007825032230
#          H           -1.638603823038    -0.891218501885     1.258190907743     1.007825032230
#          H           -2.257939823038    -2.651167501885    -0.455666092257     1.007825032230
#          H           -0.505077823038    -2.705196501885    -0.059705092257     1.007825032230
#          H           -1.059683823038    -1.939458501885    -1.603147092257     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      0.10103  B =      0.06429  C =      0.04506 [cm^-1]
#   Rotational constants: A =   3028.88969  B =   1927.45412  C =   1350.74659 [MHz]
#   Nuclear repulsion =  336.255750404653952
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 58
#   Nalpha       = 29
#   Nbeta        = 29
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-31G(D)
#     Blend: 6-31G(D)
#     Number of shells: 72
#     Number of basis functions: 135
#     Number of Cartesian functions: 135
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (6-31G(D) AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2, 4-7 entry C          line   121 file /ext3/miniconda3/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 3        entry N          line   171 file /ext3/miniconda3/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 8-22     entry H          line    51 file /ext3/miniconda3/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.136 GiB; user supplied 0.366 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       2.3484
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G(D) AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 303
#     Number of basis functions: 942
#     Number of Cartesian functions: 942
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 4.4833402208E-03.
#   Reciprocal condition number of the overlap matrix is 6.0115747960E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A        135     135
#    -------------------------
#     Total     135     135
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter SAD:  -289.09431321747593   -2.89094e+02   0.00000e+00
#    @DF-RHF iter   1:  -290.18727313310558   -1.09296e+00   3.71489e-03 ADIIS/DIIS
#    @DF-RHF iter   2:  -290.33371311271230   -1.46440e-01   1.63262e-03 ADIIS/DIIS
#    @DF-RHF iter   3:  -290.35782383448571   -2.41107e-02   3.88400e-04 ADIIS/DIIS
#    @DF-RHF iter   4:  -290.35996057600278   -2.13674e-03   1.19343e-04 ADIIS/DIIS
#    @DF-RHF iter   5:  -290.36009579858080   -1.35223e-04   2.18807e-05 DIIS
#    @DF-RHF iter   6:  -290.36010289290869   -7.09433e-06   3.27590e-06 DIIS
#    @DF-RHF iter   7:  -290.36010305063417   -1.57725e-07   1.05654e-06 DIIS
#    @DF-RHF iter   8:  -290.36010306619659   -1.55624e-08   2.53330e-07 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -15.545680     2A    -11.249155     3A    -11.249006
#        4A    -11.248988     5A    -11.215138     6A    -11.215137
#        7A    -11.210572     8A     -1.211118     9A     -1.021021
#       10A     -1.013294    11A     -0.949412    12A     -0.837217
#       13A     -0.820033    14A     -0.771950    15A     -0.652673
#       16A     -0.634971    17A     -0.599569    18A     -0.596151
#       19A     -0.564059    20A     -0.554551    21A     -0.530698
#       22A     -0.521922    23A     -0.505430    24A     -0.493543
#       25A     -0.489862    26A     -0.466553    27A     -0.460044
#       28A     -0.454165    29A     -0.348546
#
#     Virtual:
#
#       30A      0.223317    31A      0.250171    32A      0.251111
#       33A      0.274004    34A      0.278833    35A      0.295545
#       36A      0.313339    37A      0.316271    38A      0.316600
#       39A      0.332484    40A      0.342633    41A      0.348082
#       42A      0.360639    43A      0.368588    44A      0.371581
#       45A      0.376882    46A      0.401613    47A      0.417389
#       48A      0.452923    49A      0.468248    50A      0.475277
#       51A      0.700938    52A      0.722145    53A      0.732891
#       54A      0.745445    55A      0.768920    56A      0.782972
#       57A      0.800335    58A      0.832781    59A      0.857285
#       60A      0.860023    61A      0.897373    62A      0.931269
#       63A      0.942007    64A      0.968339    65A      0.971652
#       66A      1.035079    67A      1.045002    68A      1.098123
#       69A      1.110553    70A      1.112793    71A      1.147867
#       72A      1.148838    73A      1.160736    74A      1.167729
#       75A      1.176121    76A      1.176579    77A      1.181198
#       78A      1.188747    79A      1.220811    80A      1.221749
#       81A      1.233146    82A      1.238472    83A      1.274374
#       84A      1.285048    85A      1.308617    86A      1.353164
#       87A      1.386526    88A      1.424829    89A      1.616125
#       90A      1.625589    91A      1.641075    92A      1.695416
#       93A      1.778190    94A      1.781082    95A      1.923367
#       96A      1.951578    97A      1.982603    98A      2.058451
#       99A      2.086383   100A      2.111472   101A      2.219225
#      102A      2.261244   103A      2.271261   104A      2.287746
#      105A      2.310785   106A      2.314038   107A      2.346128
#      108A      2.350732   109A      2.358447   110A      2.393536
#      111A      2.473350   112A      2.535659   113A      2.569390
#      114A      2.608984   115A      2.621424   116A      2.653419
#      117A      2.656029   118A      2.663990   119A      2.692236
#      120A      2.705402   121A      2.766287   122A      2.841353
#      123A      2.923911   124A      2.964517   125A      3.035433
#      126A      3.118722   127A      3.207884   128A      3.242091
#      129A      4.459417   130A      4.620347   131A      4.628203
#      132A      4.663170   133A      4.846139   134A      4.884976
#      135A      4.920935
#
#     Final Occupation by Irrep:
#               A
#     DOCC [    29 ]
#     NA   [    29 ]
#     NB   [    29 ]
#
#   @DF-RHF Final Energy:  -290.36010306619659
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =            336.2557504046539520
#     One-Electron Energy =               -1058.3708015540928500
#     Two-Electron Energy =                 431.7549480832422546
#     Total Energy =                       -290.3601030661965865
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -1.3569736            1.2022443           -0.1547294
#  Dipole Y            :          0.5272912           -0.4756292            0.0516621
#  Dipole Z            :          0.3892970           -0.0631855            0.3261114
#  Magnitude           :                                                    0.3646352
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on cm024.hpc.nyu.edu at Thu Nov 14 15:40:11 2024
# Module time:
# 	user time   =       3.41 seconds =       0.06 minutes
# 	system time =       0.17 seconds =       0.00 minutes
# 	total time  =          4 seconds =       0.07 minutes
# Total time:
# 	user time   =      36.95 seconds =       0.62 minutes
# 	system time =       1.71 seconds =       0.03 minutes
# 	total time  =        220 seconds =       3.67 minutes

# %%
# 9. Display the DataFrame with Molecules and Their Energies
print(smiles_df[['smiles', 'n_atoms', 'energy']])
# Out:
#         smiles  n_atoms      energy
# 0     C1CCCCC1      6.0 -234.191414
# 1  C1=CC=CC=C1      6.0 -230.701592
# 2      CC(=O)O      4.0 -227.782182
# 3     C1COCCO1      6.0 -305.819130
# 4          CCO      3.0 -154.070191
# 5           CO      2.0 -115.031280
# 6          CO2      NaN         NaN
# 7     C1CNCCO1      6.0 -285.987786
# 8    CCN(CC)CC      7.0 -290.360103
