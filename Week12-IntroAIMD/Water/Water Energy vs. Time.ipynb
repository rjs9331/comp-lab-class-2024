# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to read energy data from a .ener file
def read_energy_file(file_path):
    time = []
    energy = []
    with open(file_path, 'r') as file:
        for line in file:
            # Assuming the time and energy columns are the first two columns
            # Modify the column indices based on your .ener file format
            if not line.startswith("#"):  # Skip header or comment lines
                columns = line.split()
                time.append(float(columns[0]))
                energy.append(float(columns[1]))
    return np.array(time), np.array(energy)

# File name of your energy file
file_name = 'water_aimd_1ps_every0.5fs-1.ener'

# Load energy data
time, energy = read_energy_file(file_name)

# Plot Energy vs Time
plt.figure(figsize=(10, 6))
plt.plot(time, energy, label="Energy (kJ/mol)", color="b")
plt.xlabel("Time (ps)")
plt.ylabel("Energy (kJ/mol)")
plt.title("Energy vs Time")
plt.legend()
plt.grid(True)
plt.show()
