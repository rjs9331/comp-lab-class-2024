# %%
import matplotlib.pyplot as plt 
import numpy as np

# Function to read energy data from a .ener file
def read_energy_file(file_path):
    time = []
    kinetic_energy = []
    with open(file_path, 'r') as file:
        for line in file:
            # Skip header or comment lines
            if not line.startswith("#"):  
                columns = line.split()
                time.append(float(columns[1]))  # Time is now in the second column
                kinetic_energy.append(float(columns[2]))  # Kinetic energy is in the third column
    return np.array(time), np.array(kinetic_energy)

# File name of your energy file
file_name = 'water_aimd_1ps_every0.5fs-1.ener'

# Load time and kinetic energy data
time, kinetic_energy = read_energy_file(file_name)

# Plot Kinetic Energy vs Time
plt.figure(figsize=(10, 6))
plt.plot(time, kinetic_energy, label="Kinetic Energy (kJ/mol)", color="b")
plt.xlabel("Time (ps)")
plt.ylabel("Kinetic Energy (kJ/mol)")
plt.title("Kinetic Energy vs Time")
plt.legend()
plt.grid(True)
plt.show()
