# %%
import matplotlib.pyplot as plt 
import numpy as np

# Function to read energy data from a .ener file
def read_energy_file(file_path):
    time = []
    potential_energy = []
    with open(file_path, 'r') as file:
        for line in file:
            # Skip header or comment lines
            if not line.startswith("#"):  
                columns = line.split()
                time.append(float(columns[1]))  # Time is now in the second column
                potential_energy.append(float(columns[4]))  # Potential energy is in the third column
    return np.array(time), np.array(potential_energy)

# File name of your energy file
file_name = 'NVT-1.ener'

# Load time and kinetic energy data
time, kinetic_energy = read_energy_file(file_name)

# Plot Kinetic Energy vs Time
plt.figure(figsize=(10, 6))
plt.plot(time, kinetic_energy, label="Potential Energy (kJ/mol)", color="b")
plt.xlabel("Time (ps)")
plt.ylabel("Potential Energy (kJ/mol)")
plt.title("Potential Energy vs Time")
plt.legend()
plt.grid(True)
plt.show()
